# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## List Exercises
#
# Write your code in the cell directly below the instructions for the exercises. The next cell contains a function call to test your code. Please be careful to use the exact variable names given in the exercise, or tests may fail. All variable names have been highlighted red for convenience.

# %%
### ONLY RUN THIS CELL ONCE ###

# %load_ext autoreload
exercises = {x: False for x in range(9)}

# %%
### SETUP CODE. DO NOT MODIFY ###
# %autoreload

from test_exercises import *

# %% [markdown]
# ### <span style="color:cyan">1. List Creation</span>

# %% [markdown]
# #### <span style="color:green">Exercise 1.1</span>
#
# 1. Create a list <span style="color:red">a</span> containing all the letters in the word "Python".
# 2. Find the length of list <span style="color:red">a</span> and store it in the variable <span style="color:red">length_a</span>
# 3. Print <span style="color:red">a</span>.
# 4. Print <span style="color:red">length_a</span>

# %%
# YOUR CODE GOES HERE #

# %%
test_1(0, a, length_a, exercises)

# %% [markdown]
# #### <span style="color:green">Exercise 1.2</span>
#
# 1. Create a list <span style="color:red">b</span> containing the numbers "4, 1, 3, 5, 2, 10, 2".
# 2. Find the length of list <span style="color:red">b</span> and store it in the variable <span style="color:red">length_b</span>
# 3. Print <span style="color:red">b</span>.
# 4. Print <span style="color:red">length_b</span>

# %%
# YOUR CODE GOES HERE #

# %%
test_1(1, b, length_b, exercises)

# %% [markdown]
# #### <span style="color:green">Exercise 1.3</span>
#
# 1. Create a list <span style="color:red">c</span> containing the elements:
# >5, 2, 'a', 'python', 3.2, [3, 2, 'd', 1.2]
# *Note that anything inside single or double quotes will be considered a string*
# 2. Find the length of list <span style="color:red">c</span> and store it in the variable <span style="color:red">length_c</span>
# 3. Print <span style="color:red">c</span>.
# 4. Print <span style="color:red">length_c</span>

# %%
# YOUR CODE GOES HERE #

# %%
test_1(2, a, length_a, exercises)

# %% [markdown]
# #### <span style="color:green">Exercise 1.4</span>
#
# 1. Create a list <span style="color:red">d</span> of length 6. You may use any values to create your list.
# 2. Find the length of list <span style="color:red">d</span> and store it in the variable <span style="color:red">length_d</span>
# 3. Print <span style="color:red">d</span>.
# 4. Print <span style="color:red">length_d</span>
#
# Check whether the printed length is 6 as expected.

# %%
# YOUR CODE GOES HERE #

# %%
test_1(3, a, length_a, exercises)

# %% [markdown]
# ### <span style="color:cyan">2. List Indexing</span>

# %% [markdown]
# #### <span style="color:green">Exercise 2.1</span>

# %%
example_list = [3, 2, 5, 10, 1]

# %% [markdown]
# The line of code above creates a list <span style="color:red">example_list</span> and initializes it with the given values.
#
# Complete the following tasks using *list indexing*
#
# 1. Store the first element (element at zero<sup>th</sup> index) in the variable <span style="color:red">el_0</span>.
# 2. Store the remaining elements in separate variables from <span style="color:red">el_1</span> upto and including <span style="color:red">el_4</span>.
# 3. What value do you expect will be stored in <span style="color:red">el_3</span>? Print it and check. If your prediction was incorrect, please refresh your knowledge of list indexes by going through the accompanying notebook *Chapter-3-Lists.ipynb*

# %%
# YOUR CODE GOES HERE #

# %%
test_2(4, exercises, el_0, el_1, el_2, el_3, el_4)

# %% [markdown]
# #### <span style="color:green">Exercise 2.2</span>
#
# 1. Store the value of <span style="color:red">a[2]</span> in the variable <span style="color:red">a_a</span>.
# 2. Store the value of <span style="color:red">a[0]</span> in the variable <span style="color:red">a_b</span>.
# 3. Store the value of <span style="color:red">a[-1]</span> in the variable <span style="color:red">a_c</span>.
# 4. Store the value of <span style="color:red">a[-3]</span> in the variable <span style="color:red">a_d</span>.
#
# Predict the values stored in <span style="color:red">a_a</span> upto and including <span style="color:red">a_d</span>. Print and check whether you were correct.

# %%
# YOUR CODE GOES HERE #

# %%
test_2(5, exercises, a_a, a_b, a_c, a_d)

# %% [markdown]
# ### <span style="color:cyan">3. List Slicing</span>

# %% [markdown]
# #### <span style="color:green">Exercise 3.1</span>
#
# 1. Take the third and fourth elements (elements at indexes 2 and 3) from the list <span style="color:red">b</span> and store them in the variable <span style="color:red">b_a</span>.
# ><span style="color:red">*b_a*</span> *should be a new list. I.E. Use list slicing*
# 2. Make a copy of the list <span style="color:red">b</span> and store it in <span style="color:red">b_b</span>.

# %%
# YOUR CODE GOES HERE #

# %%
test_3_1(6, b, b_a, b_b, exercises)

# %% [markdown]
# #### <span style="color:green">Exercise 3.2</span>
#
# 1. Take the first three elements from the list <span style="color:red">c</span> and store them in the variable <span style="color:red">c_a</span>.
# 2. Take the last three elements from the list <span style="color:red">c</span> and store it in <span style="color:red">c_b</span>.
# 3. Take the first element stored in the list contained in the last element of the list <span style="color:red">c</span> and store it in <span style="color:red">c_c</span>
# 4. Take the list contained in the last element of <span style="color:red">c</span> and store it in <span style="color:red">c_sublist</span>.
# ><span style="color:red">c_sublist</span> and the last element of <span style="color:red">c</span> should point to the **same** list.
# 5. Make a copy of the list contained in the last element of <span style="color:red">c</span> and store it in <span style="color:red">c_sublist_copy</span>.
# ><span style="color:red">c_sublist_other</span> should be a new list.

# %%
# YOUR CODE GOES HERE #

# %%
test_3_2(7, c, c_a, c_b, c_c, c_sublist, c_sublist_copy, exercises)

# %% [markdown]
# #### <span style="color:green">Exercise 3.3</span>
#
# 1. Append a new element 'new' to <span style="color:red">c_sublist</span>. Print <span style="color:red">c_sublist</span>.
# 2. If you print out the list in the last element of <span style="color:red">c</span>, will it contain 'new'? Print and check.
# 3. If you print out the list <span style="color:red">c_sublist_copy</span>, will it contain 'new'? Print and check.
# 4. Insert the element 'other_change' at the beginning of the list <span style="color:red">c_sublist_copy</span>. Print <span style="color:red">c_sublist_copy</span>.
# 5. If you print out the list in the last element of <span style="color:red">c</span>, will it contain 'other_change'? Print and check.
# 6. If you print out the list <span style="color:red">c_sublist</span>, will it contain 'other_change'? Print and check.

# %%
# YOUR CODE GOES HERE #

# %%
test_3_3(8, c_sublist, c_sublist_copy, exercises)
